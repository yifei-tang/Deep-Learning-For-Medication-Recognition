# %%
import tensorflow as tf
import os
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
DATA_PATH='/home/yifei/Documents/Deep-Learning-For-Medication-Recognition/Pills Images'
medication_array=['Pill1','Pill2','Pill3','Pill4','Pill5','Pill6']
IMG_SIZE=500
x_train=[]

# %%
def create_training_data():
    for pill in medication_array:
        my_path=os.path.join(DATA_PATH,pill)
        classnum=medication_array.index(pill)+1 #gives you the index at that category (1 to 6)
        
        for image in os.listdir(my_path):
            try:
                img_array=cv2.imread(os.path.join(my_path,image),cv2.IMREAD_GRAYSCALE)
                new_array=cv2.resize(img_array,(IMG_SIZE,IMG_SIZE)) #resize every image before passing it in
                x_train.append([new_array,classnum])
            except Exception as e:
                pass #accounts for corrupted images

create_training_data()
plt.imshow(x_train[0][0])

# %%
import Image
DATA_PATH='/home/yifei/Documents/Deep-Learning-For-Medication-Recognition/Pills Images/Pill1/WIN_20181221_17_30_36_Pro.jpg' 
img_array=cv2.imread(DATA_PATH)
#new_array=cv2.resize(img_array,(1000,1000))

imageBox = img_array.getbbox()
cropped=img_array.crop(imageBox)
res = cv2.resize(img_array,None,fx=0.5, fy=0.5, interpolation = cv2.INTER_LINEAR)
plt.imshow(res)
#plt.imshow(img_array)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-26-7fc6d51ab035> in <module>()
# ----> 1 import Image
#       2 DATA_PATH='/home/yifei/Documents/Deep-Learning-For-Medication-Recognition/Pills Images/Pill1/WIN_20181221_17_30_36_Pro.jpg'
#       3 img_array=cv2.imread(DATA_PATH)
#       4 #new_array=cv2.resize(img_array,(1000,1000))
#       5
#
# ImportError: No module named 'Image'

# %%
import random
import pickle
random.shuffle(x_train) #shuffle training data so it trains evenly
x=[]
y=[]

#create an array of images and an array of labels
for images, labels in x_train:
    x.append(images)
    y.append(labels)

plt.imshow(x[0])
x=np.array(x).reshape(-1,IMG_SIZE,IMG_SIZE,1)

# %%
print(x_train[0])
# Out:
# [array([[22, 46, 15, ..., 40, 42, 27],
#        [29, 43, 20, ..., 40, 43, 27],
#        [34, 42, 21, ..., 40, 45, 26],
#        ...,
#        [31, 26, 12, ..., 23, 26, 15],
#        [25, 24,  7, ..., 21, 26, 14],
#        [24, 22, 13, ..., 24, 21,  9]], dtype=uint8), 5]
